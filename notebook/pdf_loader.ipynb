# %% [markdown]
# ### RAG Pipelines- Data Ingestion to Vector DB Pipeline

# %%
import os
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pathlib import Path

# %%
### Read all the pdf's inside the directory
def process_all_pdfs(pdf_directory):
    """Process all PDF files in a directory"""
    all_documents = []
    pdf_dir = Path(pdf_directory)
    
    # Find all PDF files recursively
    pdf_files = list(pdf_dir.glob("**/*.pdf"))
    
    print(f"Found {len(pdf_files)} PDF files to process")
    
    for pdf_file in pdf_files:
        print(f"\nProcessing: {pdf_file.name}")
        try:
            loader = PyPDFLoader(str(pdf_file))
            documents = loader.load()
            
            # Add source information to metadata
            for doc in documents:
                doc.metadata['source_file'] = pdf_file.name
                doc.metadata['file_type'] = 'pdf'
            
            all_documents.extend(documents)
            print(f"  ✓ Loaded {len(documents)} pages")
            
        except Exception as e:
            print(f"  ✗ Error: {e}")
    
    print(f"\nTotal documents loaded: {len(all_documents)}")
    return all_documents

# Process all PDFs in the data directory
all_pdf_documents = process_all_pdfs("../data")
# Out:
# Found 2 PDF files to process
#
# Processing: ML4NLU_Flipped_Class_QA.pdf
#   ✓ Loaded 2 pages
#
# Processing: ML4NLU_Flipped_Class_QA_All.pdf
#   ✓ Loaded 3 pages
#
# Total documents loaded: 5

# %%
all_pdf_documents
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:13:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:13:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source_file': 'ML4NLU_Flipped_Class_QA.pdf', 'file_type': 'pdf'}, page_content='Machine Learning for Natural Language Understanding\nLecture 3 – Neural Networks\nQ: Why is the quadratic loss not ideal for binary classification?\nA: Quadratic loss penalizes errors symmetrically and leads to slow learning and poor probabilistic\ninterpretation for binary outputs. Logistic loss is better suited.\nQ: How is the output of an artificial neuron calculated?\nA: By computing a weighted sum of inputs plus bias and applying an activation function such as\nstep or sigmoid.\nQ: What are the benefits of using several neurons?\nA: They allow modeling more complex patterns and nonlinear decision boundaries.\nQ: Name two options to reduce overfitting.\nA: Regularization (L2, dropout) and early stopping.\nLecture 4 – Static Word Vectors\nQ: What is distributional semantics?\nA: The idea that word meaning emerges from the contexts in which words occur.\nQ: Name a non-ML distributional representation.\nA: Term-document matrix or co-occurrence counts.\nQ: What are input/output dimensions of Word2Vec?\nA: Input is vocabulary-sized one-hot vector; output is probability distribution over vocabulary.\nQ: What is softmax?\nA: A function converting scores into a probability distribution.\nLecture 5 – Language Models\nQ: What is a neural language model?\nA: A model using neural networks to predict next-token probabilities, overcoming sparsity of\nn-grams.\nQ: Contextualized vs static embeddings?\nA: Contextualized embeddings depend on sentence context; static embeddings do not.\nQ: How do RNNs overcome limited window size?\nA: By maintaining a hidden state that carries information over time.\nQ: How many gates are in an LSTM?\nA: Three gates (input, forget, output) plus cell state.\nLecture 6 – Transformer Encoder\nQ: Which context does W2V vs RNN capture?\nA: W2V captures local window context; RNN captures sequential context.\nQ: What is self-attention?\nA: A mechanism allowing tokens to attend to each other within a sequence.\nQ: What context does BERT capture?\nA: Bidirectional sentence-level context.\nQ: What does an attention weight do?\nA: It determines how much one token influences another.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:13:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:13:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source_file': 'ML4NLU_Flipped_Class_QA.pdf', 'file_type': 'pdf'}, page_content='Lecture 7 – Transformer Decoding\nQ: What block is not used in GPT decoder vs BERT?\nA: Encoder-decoder cross-attention.\nQ: What is in-context learning?\nA: Learning tasks from prompts without weight updates.\nQ: Where do decoders fail?\nA: Exact arithmetic or factual recall without tools.\nLecture 8 – Pretraining\nQ: Training vs inference?\nA: Training updates weights; inference only predicts outputs.\nQ: Typical pretraining objective?\nA: MLM for encoders, next-token prediction for decoders.\nQ: Main source of pretraining data?\nA: Web data such as Common Crawl.\nQ: Context window of Llama 3?\nA: Up to 128k tokens (final stage).\nLecture 9 – Post Training\nQ: Post-training vs pretraining?\nA: Post-training aligns models with tasks and human preferences using labeled data.\nQ: Typical NLU benchmarks?\nA: QA, sentiment analysis, NLI, summarization.\nQ: SFT vs RL?\nA: SFT uses labeled answers; RL optimizes via reward models.\nLecture 10 – Prompting & Tools\nQ: Few-shot supervised vs in-context learning?\nA: Supervised updates weights; in-context does not.\nQ: Typical elements of a prompt?\nA: Instruction, context, examples, format constraints.\nQ: Prompting techniques?\nA: Chain-of-thought, self-consistency, demonstrations.\nQ: Tasks LLMs handle poorly?\nA: Arithmetic, real-time data, long-term memory.\nQ: Techniques to mitigate this?\nA: Tool use, RAG, calculators, web search.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:16:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:16:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA_All.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1', 'source_file': 'ML4NLU_Flipped_Class_QA_All.pdf', 'file_type': 'pdf'}, page_content='Lecture 1 – ML4NLU Basics\nQ: What is Natural Language Understanding (NLU)?\nA: NLU is the ability of a machine to understand, interpret, and derive meaning from human\nlanguage.\nQ: What is the difference between rule-based and machine learning approaches?\nA: Rule-based systems rely on handcrafted rules, while ML systems learn patterns automatically\nfrom data.\nQ: Why is ML preferred over symbolic approaches for NLU?\nA: Because ML scales better, handles ambiguity, and adapts to noisy real-world language.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:16:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:16:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA_All.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2', 'source_file': 'ML4NLU_Flipped_Class_QA_All.pdf', 'file_type': 'pdf'}, page_content='Lecture 2 – Learning & Evaluation\nQ: What is supervised learning?\nA: A learning paradigm where models are trained using labeled input-output pairs.\nQ: What is overfitting?\nA: When a model fits training data too closely and performs poorly on unseen data.\nQ: Why do we need train/dev/test splits?\nA: To fairly evaluate generalization and prevent information leakage.\nQ: What is accuracy not suitable for?\nA: Imbalanced datasets, where precision/recall are more informative.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:16:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:16:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA_All.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3', 'source_file': 'ML4NLU_Flipped_Class_QA_All.pdf', 'file_type': 'pdf'}, page_content='Lecture 3–10 – Core Flipped Classroom Questions\nQ: Why is quadratic loss not ideal for binary classification?\nA: It leads to slow learning and poor probabilistic interpretation compared to logistic loss.\nQ: What is distributional semantics?\nA: Word meaning emerges from the contexts in which words appear.\nQ: Static vs contextual embeddings?\nA: Static embeddings are context-independent; contextual embeddings depend on sentence\ncontext.\nQ: What is self-attention?\nA: A mechanism allowing tokens to attend to other tokens within the same sequence.\nQ: What is in-context learning?\nA: Learning tasks from prompts without updating model parameters.\nQ: Training vs inference?\nA: Training updates model weights; inference only performs forward prediction.\nQ: What is post-training?\nA: Aligning pretrained models with tasks and human preferences using labeled data.\nQ: What are typical elements of a prompt?\nA: Instruction, context, examples, and formatting constraints.\nQ: Which tasks do LLMs handle poorly?\nA: Exact arithmetic, real-time information, and factual verification.\nQ: How are these limitations mitigated?\nA: Using tools such as calculators, web search, and RAG.')]

# %%
### Text splitting get into chunks

def split_documents(documents,chunk_size=1000,chunk_overlap=200):
    """Split documents into smaller chunks for better RAG performance"""
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len,
        separators=["\n\n", "\n", " ", ""]
    )
    split_docs = text_splitter.split_documents(documents)
    print(f"Split {len(documents)} documents into {len(split_docs)} chunks")
    
    # Show example of a chunk
    if split_docs:
        print(f"\nExample chunk:")
        print(f"Content: {split_docs[0].page_content[:200]}...")
        print(f"Metadata: {split_docs[0].metadata}")
    
    return split_docs

# %%
chunks=split_documents(all_pdf_documents)
chunks
# Out:
# Split 5 documents into 9 chunks
#
# Example chunk:
# Content: Machine Learning for Natural Language Understanding
# Lecture 3 – Neural Networks
# Q: Why is the quadratic loss not ideal for binary classification?
# A: Quadratic loss penalizes errors symmetrically and l...
# Metadata: {'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:13:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:13:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source_file': 'ML4NLU_Flipped_Class_QA.pdf', 'file_type': 'pdf'}
# [Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:13:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:13:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source_file': 'ML4NLU_Flipped_Class_QA.pdf', 'file_type': 'pdf'}, page_content='Machine Learning for Natural Language Understanding\nLecture 3 – Neural Networks\nQ: Why is the quadratic loss not ideal for binary classification?\nA: Quadratic loss penalizes errors symmetrically and leads to slow learning and poor probabilistic\ninterpretation for binary outputs. Logistic loss is better suited.\nQ: How is the output of an artificial neuron calculated?\nA: By computing a weighted sum of inputs plus bias and applying an activation function such as\nstep or sigmoid.\nQ: What are the benefits of using several neurons?\nA: They allow modeling more complex patterns and nonlinear decision boundaries.\nQ: Name two options to reduce overfitting.\nA: Regularization (L2, dropout) and early stopping.\nLecture 4 – Static Word Vectors\nQ: What is distributional semantics?\nA: The idea that word meaning emerges from the contexts in which words occur.\nQ: Name a non-ML distributional representation.\nA: Term-document matrix or co-occurrence counts.\nQ: What are input/output dimensions of Word2Vec?'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:13:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:13:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source_file': 'ML4NLU_Flipped_Class_QA.pdf', 'file_type': 'pdf'}, page_content='Q: Name a non-ML distributional representation.\nA: Term-document matrix or co-occurrence counts.\nQ: What are input/output dimensions of Word2Vec?\nA: Input is vocabulary-sized one-hot vector; output is probability distribution over vocabulary.\nQ: What is softmax?\nA: A function converting scores into a probability distribution.\nLecture 5 – Language Models\nQ: What is a neural language model?\nA: A model using neural networks to predict next-token probabilities, overcoming sparsity of\nn-grams.\nQ: Contextualized vs static embeddings?\nA: Contextualized embeddings depend on sentence context; static embeddings do not.\nQ: How do RNNs overcome limited window size?\nA: By maintaining a hidden state that carries information over time.\nQ: How many gates are in an LSTM?\nA: Three gates (input, forget, output) plus cell state.\nLecture 6 – Transformer Encoder\nQ: Which context does W2V vs RNN capture?\nA: W2V captures local window context; RNN captures sequential context.\nQ: What is self-attention?'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:13:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:13:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'source_file': 'ML4NLU_Flipped_Class_QA.pdf', 'file_type': 'pdf'}, page_content='Lecture 6 – Transformer Encoder\nQ: Which context does W2V vs RNN capture?\nA: W2V captures local window context; RNN captures sequential context.\nQ: What is self-attention?\nA: A mechanism allowing tokens to attend to each other within a sequence.\nQ: What context does BERT capture?\nA: Bidirectional sentence-level context.\nQ: What does an attention weight do?\nA: It determines how much one token influences another.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:13:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:13:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source_file': 'ML4NLU_Flipped_Class_QA.pdf', 'file_type': 'pdf'}, page_content='Lecture 7 – Transformer Decoding\nQ: What block is not used in GPT decoder vs BERT?\nA: Encoder-decoder cross-attention.\nQ: What is in-context learning?\nA: Learning tasks from prompts without weight updates.\nQ: Where do decoders fail?\nA: Exact arithmetic or factual recall without tools.\nLecture 8 – Pretraining\nQ: Training vs inference?\nA: Training updates weights; inference only predicts outputs.\nQ: Typical pretraining objective?\nA: MLM for encoders, next-token prediction for decoders.\nQ: Main source of pretraining data?\nA: Web data such as Common Crawl.\nQ: Context window of Llama 3?\nA: Up to 128k tokens (final stage).\nLecture 9 – Post Training\nQ: Post-training vs pretraining?\nA: Post-training aligns models with tasks and human preferences using labeled data.\nQ: Typical NLU benchmarks?\nA: QA, sentiment analysis, NLI, summarization.\nQ: SFT vs RL?\nA: SFT uses labeled answers; RL optimizes via reward models.\nLecture 10 – Prompting & Tools\nQ: Few-shot supervised vs in-context learning?'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:13:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:13:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2', 'source_file': 'ML4NLU_Flipped_Class_QA.pdf', 'file_type': 'pdf'}, page_content='A: QA, sentiment analysis, NLI, summarization.\nQ: SFT vs RL?\nA: SFT uses labeled answers; RL optimizes via reward models.\nLecture 10 – Prompting & Tools\nQ: Few-shot supervised vs in-context learning?\nA: Supervised updates weights; in-context does not.\nQ: Typical elements of a prompt?\nA: Instruction, context, examples, format constraints.\nQ: Prompting techniques?\nA: Chain-of-thought, self-consistency, demonstrations.\nQ: Tasks LLMs handle poorly?\nA: Arithmetic, real-time data, long-term memory.\nQ: Techniques to mitigate this?\nA: Tool use, RAG, calculators, web search.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:16:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:16:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA_All.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1', 'source_file': 'ML4NLU_Flipped_Class_QA_All.pdf', 'file_type': 'pdf'}, page_content='Lecture 1 – ML4NLU Basics\nQ: What is Natural Language Understanding (NLU)?\nA: NLU is the ability of a machine to understand, interpret, and derive meaning from human\nlanguage.\nQ: What is the difference between rule-based and machine learning approaches?\nA: Rule-based systems rely on handcrafted rules, while ML systems learn patterns automatically\nfrom data.\nQ: Why is ML preferred over symbolic approaches for NLU?\nA: Because ML scales better, handles ambiguity, and adapts to noisy real-world language.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:16:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:16:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA_All.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2', 'source_file': 'ML4NLU_Flipped_Class_QA_All.pdf', 'file_type': 'pdf'}, page_content='Lecture 2 – Learning & Evaluation\nQ: What is supervised learning?\nA: A learning paradigm where models are trained using labeled input-output pairs.\nQ: What is overfitting?\nA: When a model fits training data too closely and performs poorly on unseen data.\nQ: Why do we need train/dev/test splits?\nA: To fairly evaluate generalization and prevent information leakage.\nQ: What is accuracy not suitable for?\nA: Imbalanced datasets, where precision/recall are more informative.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:16:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:16:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA_All.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3', 'source_file': 'ML4NLU_Flipped_Class_QA_All.pdf', 'file_type': 'pdf'}, page_content='Lecture 3–10 – Core Flipped Classroom Questions\nQ: Why is quadratic loss not ideal for binary classification?\nA: It leads to slow learning and poor probabilistic interpretation compared to logistic loss.\nQ: What is distributional semantics?\nA: Word meaning emerges from the contexts in which words appear.\nQ: Static vs contextual embeddings?\nA: Static embeddings are context-independent; contextual embeddings depend on sentence\ncontext.\nQ: What is self-attention?\nA: A mechanism allowing tokens to attend to other tokens within the same sequence.\nQ: What is in-context learning?\nA: Learning tasks from prompts without updating model parameters.\nQ: Training vs inference?\nA: Training updates model weights; inference only performs forward prediction.\nQ: What is post-training?\nA: Aligning pretrained models with tasks and human preferences using labeled data.\nQ: What are typical elements of a prompt?\nA: Instruction, context, examples, and formatting constraints.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-01-19T14:16:57+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-01-19T14:16:57+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '../data/pdf/ML4NLU_Flipped_Class_QA_All.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3', 'source_file': 'ML4NLU_Flipped_Class_QA_All.pdf', 'file_type': 'pdf'}, page_content='A: Aligning pretrained models with tasks and human preferences using labeled data.\nQ: What are typical elements of a prompt?\nA: Instruction, context, examples, and formatting constraints.\nQ: Which tasks do LLMs handle poorly?\nA: Exact arithmetic, real-time information, and factual verification.\nQ: How are these limitations mitigated?\nA: Using tools such as calculators, web search, and RAG.')]

# %% [markdown]
# ### embedding and vectorStoreDB

# %%
import numpy as np
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.config import Settings
import uuid # this is to store the datas with unique IDs.
from typing import List, Dict, Any, Tuple
from sklearn.metrics.pairwise import cosine_similarity
import os

# %%
class EmbeddingManager:
    """Handles document embedding generation using SentenceTransformer"""
    
    def __init__(self, model_name: str = "all-MiniLM-L6-v2"):
        """
        Initialize the embedding manager
        
        Args:
            model_name: HuggingFace model name for sentence embeddings
        """
        self.model_name = model_name
        self.model = None
        self._load_model()

    def _load_model(self):
        """Load the SentenceTransformer model"""
        try:
            print(f"Loading embedding model: {self.model_name}")
            self.model = SentenceTransformer(self.model_name)
            print(f"Model loaded successfully. Embedding dimension: {self.model.get_sentence_embedding_dimension()}")
        except Exception as e:
            print(f"Error loading model {self.model_name}: {e}")
            raise

    def generate_embeddings(self, texts: List[str]) -> np.ndarray:
        """
        Generate embeddings for a list of texts
        
        Args:
            texts: List of text strings to embed
            
        Returns:
            numpy array of embeddings with shape (len(texts), embedding_dim)
        """
        if not self.model:
            raise ValueError("Model not loaded")
        
        print(f"Generating embeddings for {len(texts)} texts...")
        embeddings = self.model.encode(texts, show_progress_bar=True)
        print(f"Generated embeddings with shape: {embeddings.shape}")
        return embeddings

    '''def get_embedding_dimension(self) -> int:
        """Get the embedding dimension of the model"""
        if not self.model:
            raise ValueError("Model not loaded")
        return self.model.get_sentence_embedding_dimension()'''
    

## initialize the embedding manager

embedding_manager = EmbeddingManager()
embedding_manager
# Out:
# Loading embedding model: all-MiniLM-L6-v2
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 7306.41it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model loaded successfully. Embedding dimension: 384

# %% [markdown]
# ### Vectore Store

# %%
class VectorStore:
    """Manages document embeddings in a ChromaDB vector store"""
    
    def __init__(self, collection_name: str = "pdf_documents", persist_directory: str = "../data/vector_store"):
        """
        Initialize the vector store
        
        Args:
            collection_name: Name of the ChromaDB collection
            persist_directory: Directory to persist the vector store
        """
        self.collection_name = collection_name
        self.persist_directory = persist_directory
        self.client = None
        self.collection = None
        self._initialize_store()

    def _initialize_store(self):
        """Initialize ChromaDB client and collection"""
        try:
            # Create persistent ChromaDB client
            os.makedirs(self.persist_directory, exist_ok=True)
            self.client = chromadb.PersistentClient(path=self.persist_directory)
            
            # Get or create collection
            self.collection = self.client.get_or_create_collection(
                name=self.collection_name,
                metadata={"description": "PDF document embeddings for RAG"}
            )
            print(f"Vector store initialized. Collection: {self.collection_name}")
            print(f"Existing documents in collection: {self.collection.count()}")
            
        except Exception as e:
            print(f"Error initializing vector store: {e}")
            raise

    def add_documents(self, documents: List[Any], embeddings: np.ndarray):
        """
        Add documents and their embeddings to the vector store
        
        Args:
            documents: List of LangChain documents
            embeddings: Corresponding embeddings for the documents
        """
        if len(documents) != len(embeddings):
            raise ValueError("Number of documents must match number of embeddings")
        
        print(f"Adding {len(documents)} documents to vector store...")
        
        # Prepare data for ChromaDB
        ids = []
        metadatas = []
        documents_text = []
        embeddings_list = []
        
        for i, (doc, embedding) in enumerate(zip(documents, embeddings)):
            # Generate unique ID
            doc_id = f"doc_{uuid.uuid4().hex[:8]}_{i}"
            ids.append(doc_id)
            
            # Prepare metadata
            metadata = dict(doc.metadata)
            metadata['doc_index'] = i
            metadata['content_length'] = len(doc.page_content)
            metadatas.append(metadata)
            
            # Document content
            documents_text.append(doc.page_content)
            
            # Embedding
            embeddings_list.append(embedding.tolist())
        
        # Add to collection
        try:
            self.collection.add(
                ids=ids,
                embeddings=embeddings_list,
                metadatas=metadatas,
                documents=documents_text
            )
            print(f"Successfully added {len(documents)} documents to vector store")
            print(f"Total documents in collection: {self.collection.count()}")
            
        except Exception as e:
            print(f"Error adding documents to vector store: {e}")
            raise

vectorstore=VectorStore()
vectorstore
# Out:
# Vector store initialized. Collection: pdf_documents
# Existing documents in collection: 0

# %%
### Convert the text to embeddings
texts = [doc.page_content for doc in chunks]

#Generate embedding
embeddings = embedding_manager.generate_embeddings(texts)

## Store into vectore database
vectorstore.add_documents(chunks, embeddings)
# Out:
# Generating embeddings for 9 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
# Generated embeddings with shape: (9, 384)
# Adding 9 documents to vector store...
# Successfully added 9 documents to vector store
# Total documents in collection: 9

# %% [markdown]
# ### Retriever Pipeline From VectorStore

# %%
class RAGRetriever:
    """Handles query-based retrieval from the vector store"""
    
    def __init__(self, vector_store: VectorStore, embedding_manager: EmbeddingManager):
        """
        Initialize the retriever
        
        Args:
            vector_store: Vector store containing document embeddings
            embedding_manager: Manager for generating query embeddings
        """
        self.vector_store = vector_store
        self.embedding_manager = embedding_manager
    
    def retrieve(self, query: str, top_k: int = 5, score_threshold: float = 0.0) -> List[Dict[str, Any]]:
        """
        Retrieve relevant documents for a query
        
        Args:
            query: The search query
            top_k: Number of top results to return
            score_threshold: Minimum similarity score threshold
            
        Returns:
            List of dictionaries containing retrieved documents and metadata
        """
        print(f"Retrieving documents for query: '{query}'")
        print(f"Top K: {top_k}, Score threshold: {score_threshold}")
        
        # Generate query embedding
        query_embedding = self.embedding_manager.generate_embeddings([query])[0]
        
        # Search in vector store
        try:
            results = self.vector_store.collection.query(
                query_embeddings=[query_embedding.tolist()],
                n_results=top_k
            )
            
            # Process results
            retrieved_docs = []
            
            if results['documents'] and results['documents'][0]:
                documents = results['documents'][0]
                metadatas = results['metadatas'][0]
                distances = results['distances'][0]
                ids = results['ids'][0]
                
                for i, (doc_id, document, metadata, distance) in enumerate(zip(ids, documents, metadatas, distances)):
                    # Convert distance to similarity score (ChromaDB uses cosine distance)
                    similarity_score = 1 - distance
                    
                    if similarity_score >= score_threshold:
                        retrieved_docs.append({
                            'id': doc_id,
                            'content': document,
                            'metadata': metadata,
                            'similarity_score': similarity_score,
                            'distance': distance,
                            'rank': i + 1
                        })
                
                print(f"Retrieved {len(retrieved_docs)} documents (after filtering)")
            else:
                print("No documents found")
            
            return retrieved_docs
            
        except Exception as e:
            print(f"Error during retrieval: {e}")
            return []
        
rag_retriever = RAGRetriever(vectorstore, embedding_manager)

# %%
rag_retriever

# %%
rag_retriever.retrieve("What is Natural Language Understanding")
# Out:
# Retrieving documents for query: 'What is Natural Language Understanding'
# Top K: 5, Score threshold: 0.0
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00,  2.31it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 1 documents (after filtering)
# [{'id': 'doc_6142b039_5',
#   'content': 'Lecture 1 – ML4NLU Basics\nQ: What is Natural Language Understanding (NLU)?\nA: NLU is the ability of a machine to understand, interpret, and derive meaning from human\nlanguage.\nQ: What is the difference between rule-based and machine learning approaches?\nA: Rule-based systems rely on handcrafted rules, while ML systems learn patterns automatically\nfrom data.\nQ: Why is ML preferred over symbolic approaches for NLU?\nA: Because ML scales better, handles ambiguity, and adapts to noisy real-world language.',
#   'metadata': {'total_pages': 3,
#    'trapped': '/False',
#    'moddate': '2026-01-19T14:16:57+00:00',
#    'creationdate': '2026-01-19T14:16:57+00:00',
#    'page': 0,
#    'source_file': 'ML4NLU_Flipped_Class_QA_All.pdf',
#    'author': '(anonymous)',
#    'doc_index': 5,
#    'title': '(anonymous)',
#    'creator': '(unspecified)',
#    'keywords': '',
#    'file_type': 'pdf',
#    'page_label': '1',
#    'subject': '(unspecified)',
#    'content_length': 505,
#    'producer': 'ReportLab PDF Library - www.reportlab.com',
#    'source': '../data/pdf/ML4NLU_Flipped_Class_QA_All.pdf'},
#   'similarity_score': 0.3001437783241272,
#   'distance': 0.6998562216758728,
#   'rank': 1}]
